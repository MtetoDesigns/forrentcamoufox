# %%
import pandas as pd

# %%
forrent_data = pd.read_csv('forrent_ca_properties.csv')
df = forrent_data.copy()

# %%
df.head()
# Out:
#                                                  URL   Price  \
# 0  https://www.forrent.com/ca/stevenson-ranch/imt...     NaN
# 1  https://www.forrent.com/ca/mill-valley/8-dell-...  $3,000
# 2  https://www.forrent.com/ca/west-hollywood/1230...  $2,700
# 3  https://www.forrent.com/ca/santa-clarita/18123...  $3,300
# 4  https://www.forrent.com/ca/chula-vista/del-oro...     NaN
#
#                                    Address                      Date  \
# 0                                      NaN  2025-12-04T15:26:56.953Z
# 1         8 Dell St, Mill Valley, CA 94941  2025-11-06T23:14:46.170Z
# 2  1230 Horn Ave, West Hollywood, CA 90069  2025-12-04T03:41:23.207Z
# 3   18123 Erik Ct, Santa Clarita, CA 91387  2025-12-04T20:06:14.433Z
# 4                                      NaN  2025-12-02T17:27:56.857Z
#
#           Contact Bedrooms Bathrooms           SqFt      Availability
# 0  (661) 481-7846      NaN       NaN            NaN               NaN
# ...

# %%
df.shape
# Out:
# (40, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   URL           40 non-null     object
#  1   Price         27 non-null     object
#  2   Address       27 non-null     object
#  3   Date          40 non-null     object
#  4   Contact       37 non-null     object
#  5   Bedrooms      27 non-null     object
#  6   Bathrooms     27 non-null     object
#  7   SqFt          27 non-null     object
#  8   Availability  27 non-null     object
# dtypes: object(9)
# memory usage: 2.9+ KB

# %%
df.isna().sum()
# Out:
# URL              0
# Price           13
# Address         13
# Date             0
# Contact          3
# Bedrooms        13
# Bathrooms       13
# SqFt            13
# Availability    13
# dtype: int64
